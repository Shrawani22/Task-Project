# %% [markdown]
# # Shrawani Thakare
# ## Task 1
# ### Predict the percentage of an student based on the no. of study hours.
# ### Dataset : http://bit.ly/w-data

# %%
import numpy as np
import pandas as pdb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = "http://bit.ly/w-data"

# %%
l_data = pd.read_csv(url)
print("data imported")

l_data.head(10)
# Out:
# data imported
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
l_data.plot(x="Hours", y="Scores")
l_data.plot(x='Hours', y='Scores')
plt.title("Hours vs Scores")
# Out:
# Text(0.5, 1.0, 'Hours vs Scores')

# %%
l_data.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
l_data.plot.scatter(x="Hours", y="Scores")
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Scores'>

# %%
l_data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X = l_data.iloc[:, :-1].values
y = l_data.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
line= regressor.coef_*X_train + regressor.intercept_

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train, line)
plt.show()

# %%
print(X_test)
y_pred = regressor.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
print("Training Score", regressor.score(X_train,y_train))
print("Testing Score", regressor.score(X_train,y_train))
# Out:
# Training Score 0.9515510725211552
# Testing Score 0.9515510725211552

# %%
print(regressor.intercept_)
# Out:
# 2.018160041434683

# %%
print(regressor.coef_)
# Out:
# [9.91065648]

# %%
df.plot(kind="bar", figsize=(7,7))
plt.show()

# %%
hours= 9.25
test= np.array([hours])
test= test.reshape(-1,1)
own_pred= regressor.predict(test)
print("no of hours= {}".format(hours))
print("predicted score={}".format(own_pred[0]))
# Out:
# no of hours= 9.25
# predicted score=93.69173248737538

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.183859899002975
# Mean Squared Error: 21.5987693072174
# Root Mean Squared Error: 4.6474476121003665

# %%
print("We can see that the value of root mean squared error is 4.64, which is less than 10% of the mean value of the percentages of all the students i.e. 51.48. This means that algorithm did a decent job.")
# Out:
# We can see that the value of root mean squared error is 4.64, which is less than 10% of the mean value of the percentages of all the students i.e. 51.48. This means that algorithm did a decent job.

# %% [markdown]
#  ### from the above, we can conclude that Predicted score is 93.69% ,if a student studies for 9.25 hrs/ day.
